# %% [markdown]
# ---

# %% [markdown]
# # Demo

# %% [markdown]
# This notebook provides a demonstration of the simulator.
#
# **[Prerequisites]**
# This demo was executed on Google Colab. To run this notebook, please upload the following files to your Colab environment:
#
# - `collostructional_analysis.py`
# - `sim1.py`
# - `sim2.py`
# - `sim3.py`

# %% [markdown]
# If you don't have the files locally, you can run commands like the following in a Colab cell to download them directly from the public repository.
#
# *(Note: Please adjust the URLs accordingly if the repository structure changes in the future.)*
#
# ```
# !wget https://raw.githubusercontent.com/garage-phi/collostructional-analysis-python/main/core/collostructional_analysis.py
#
# !wget https://raw.githubusercontent.com/garage-phi/collostructional-analysis-python/main/simulator/sim1.py
#
# !wget https://raw.githubusercontent.com/garage-phi/collostructional-analysis-python/main/simulator/sim2.py
#
# !wget https://raw.githubusercontent.com/garage-phi/collostructional-analysis-python/main/simulator/sim3.py
# ```

# %% [markdown]
# ## Simulator 1

# %%
from sim1 import CollostructionalComparisonSimulatorNCWr

simulator1 = CollostructionalComparisonSimulatorNCWr()

# %%
simulator1.display()

# %% [markdown]
# ## Simulator 2

# %%
from sim2 import CollostructionalComparisonSimulatorKMbr

simulator2 = CollostructionalComparisonSimulatorKMbr()

# %%
simulator2.display()

# %% [markdown]
# ## Simulator 3

# %%
from sim3 import CollostructionalComparisonSimulatorNsbr

simulator3 = CollostructionalComparisonSimulatorNsbr()

# %%
simulator3.display()

# %% [markdown]
# ---
